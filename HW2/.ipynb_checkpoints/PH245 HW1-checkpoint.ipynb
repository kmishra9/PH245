# %% [markdown]
# # PH 245 Homework 2
# Kunal Mishra

# %%
#Loading Libraries
library(ggplot2)

# Loading Data
data = read.table(file="Data-HW2-Bodyfat.txt", header=FALSE)
colnames(data) = c('Case Number', "BroznekBF", 
                   "SiriBF", "Density", 
                   "Age", "Weight", "Height", "AdiposityIndex",
                   "FatFreeWeight", "NeckCirc", "ChestCirc",
                   "AbdomenCirc", "HipCirc", "ThighCirc",
                   "KneeCirc", "AnkleCirc", 
                   "ExtendedBicepsCirc", "ForearmCirc",
                   "WristCirc")

head(data)
# Out:
#   Case Number BroznekBF SiriBF Density Age Weight Height AdiposityIndex
# 1 1           12.6      12.3   1.0708  23  154.25 67.75  23.7
# 2 2            6.9       6.1   1.0853  22  173.25 72.25  23.4
# 3 3           24.6      25.3   1.0414  22  154.00 66.25  24.7
# 4 4           10.9      10.4   1.0751  26  184.75 72.25  24.9
# 5 5           27.8      28.7   1.0340  24  184.25 71.25  25.6
# 6 6           20.6      20.9   1.0502  24  210.25 74.75  26.5
#   FatFreeWeight NeckCirc ChestCirc AbdomenCirc HipCirc ThighCirc KneeCirc
# 1 134.9         36.2      93.1      85.2        94.5   59.0      37.3
# 2 161.3         38.5      93.6      83.0        98.7   58.7      37.3
# 3 116.0         34.0      95.8      87.9        99.2   59.6      38.9
# 4 164.7         37.4     101.8      86.4       101.2   60.1      37.3
# 5 133.1         34.4      97.3     100.0       101.9   63.2      42.2
# 6 167.0         39.0     104.5      94.4       107.8   66.0      42.0
#   AnkleCirc ExtendedBicepsCirc ForearmCirc WristCirc
# 1 21.9      32.0               27.4        17.1
# 2 23.4      30.5               28.9        18.2
# 3 24.0      28.8               25.2        16.6
# 4 22.8      32.4               29.4        18.2
# 5 24.0      32.2               27.7        17.7
# 6 25.6      35.7               30.6        18.8

# %% [markdown]
# #### Exploratory Data Analysis (EDA)

# %%
ggplot(data=data, aes(x = Age)) + geom_histogram(binwidth=1)
ggplot(data=data, aes(x = Weight)) + geom_histogram(binwidth=5)
ggplot(data=data, aes(x = Height)) + geom_histogram(binwidth=.5)
# Out:
# plot without title
# plot without title
# plot without title

# %%
print(nrow(data))
summary(data)
cor(data)
# Out:
# [1] 252
#   Case Number       BroznekBF         SiriBF         Density
#  Min.   :  1.00   Min.   : 0.00   Min.   : 0.00   Min.   :0.995
#  1st Qu.: 63.75   1st Qu.:12.80   1st Qu.:12.47   1st Qu.:1.041
#  Median :126.50   Median :19.00   Median :19.20   Median :1.055
#  Mean   :126.50   Mean   :18.94   Mean   :19.15   Mean   :1.056
#  3rd Qu.:189.25   3rd Qu.:24.60   3rd Qu.:25.30   3rd Qu.:1.070
#  Max.   :252.00   Max.   :45.10   Max.   :47.50   Max.   :1.109
#       Age            Weight          Height      AdiposityIndex
#  Min.   :22.00   Min.   :118.5   Min.   :29.50   Min.   :18.10
#  1st Qu.:35.75   1st Qu.:159.0   1st Qu.:68.25   1st Qu.:23.10
#  Median :43.00   Median :176.5   Median :70.00   Median :25.05
#  Mean   :44.88   Mean   :178.9   Mean   :70.15   Mean   :25.44
#  3rd Qu.:54.00   3rd Qu.:197.0   3rd Qu.:72.25   3rd Qu.:27.32
#  Max.   :81.00   Max.   :363.1   Max.   :77.75   Max.   :48.90
#  FatFreeWeight      NeckCirc       ChestCirc       AbdomenCirc
#  Min.   :105.9   Min.   :31.10   Min.   : 79.30   Min.   : 69.40
#  1st Qu.:131.3   1st Qu.:36.40   1st Qu.: 94.35   1st Qu.: 84.58
#  Median :141.6   Median :38.00   Median : 99.65   Median : 90.95
#  Mean   :143.7   Mean   :37.99   Mean   :100.82   Mean   : 92.56
#  3rd Qu.:153.9   3rd Qu.:39.42   3rd Qu.:105.38   3rd Qu.: 99.33
#  Max.   :240.5   Max.   :51.20   Max.   :136.20   Max.   :148.10
#     HipCirc        ThighCirc        KneeCirc       AnkleCirc
#  Min.   : 85.0   Min.   :47.20   Min.   :33.00   Min.   :19.1
#  1st Qu.: 95.5   1st Qu.:56.00   1st Qu.:36.98   1st Qu.:22.0
#  Median : 99.3   Median :59.00   Median :38.50   Median :22.8
#  Mean   : 99.9   Mean   :59.41   Mean   :38.59   Mean   :23.1
#  3rd Qu.:103.5   3rd Qu.:62.35   3rd Qu.:39.92   3rd Qu.:24.0
#  Max.   :147.7   Max.   :87.30   Max.   :49.10   Max.   :33.9
#  ExtendedBicepsCirc  ForearmCirc      WristCirc
#  Min.   :24.80      Min.   :21.00   Min.   :15.80
#  1st Qu.:30.20      1st Qu.:27.30   1st Qu.:17.60
#  Median :32.05      Median :28.70   Median :18.30
#  Mean   :32.27      Mean   :28.66   Mean   :18.23
#  3rd Qu.:34.33      3rd Qu.:30.00   3rd Qu.:18.80
#  Max.   :45.00      Max.   :34.90   Max.   :21.40
#                    Case Number  BroznekBF   SiriBF      Density     Age
# Case Number         1.000000000  0.11095086  0.11182544 -0.10960539  0.34125350
# BroznekBF           0.110950863  1.00000000  0.99974434 -0.98808673  0.28917352
# SiriBF              0.111825441  0.99974434  1.00000000 -0.98778240  0.29145844
# Density            -0.109605390 -0.98808673 -0.98778240  1.00000000 -0.27763721
# Age                 0.341253503  0.28917352  0.29145844 -0.27763721  1.00000000
# Weight              0.033727935  0.61315611  0.61241400 -0.59406188 -0.01274609
# Height              0.040943134 -0.08910641 -0.08949538  0.09788114 -0.17164514
# AdiposityIndex      0.047717462  0.72799418  0.72748388 -0.71473204  0.11885126
# FatFreeWeight      -0.040092608  0.02013209  0.01937491 -0.00574871 -0.23790534
# NeckCirc            0.071112330  0.49148893  0.49059185 -0.47296636  0.11350519
# ChestCirc           0.120514823  0.70288516  0.70262034 -0.68259865  0.17644968
# AbdomenCirc         0.121719735  0.81370622  0.81343228 -0.79895463  0.23040942
# HipCirc            -0.023736967  0.62569993  0.62520092 -0.60933143 -0.05033212
# ThighCirc          -0.080708189  0.56128438  0.55960753 -0.55309098 -0.20009576
# KneeCirc            0.047938697  0.50778587  0.50866524 -0.49504035  0.01751569
# AnkleCirc          -0.070644290  0.26678256  0.26596977 -0.26489003 -0.10505810
# ExtendedBicepsCirc -0.015676890  0.49303089  0.49327113 -0.48710872 -0.04116212
# ForearmCirc         0.001959724  0.36327744  0.36138690 -0.35164842 -0.08505555
# WristCirc           0.081845381  0.34757276  0.34657486 -0.32571598  0.21353062
#                    Weight      Height      AdiposityIndex FatFreeWeight
# Case Number         0.03372794  0.04094313  0.04771746    -0.04009261
# BroznekBF           0.61315611 -0.08910641  0.72799418     0.02013209
# SiriBF              0.61241400 -0.08949538  0.72748388     0.01937491
# Density            -0.59406188  0.09788114 -0.71473204    -0.00574871
# Age                -0.01274609 -0.17164514  0.11885126    -0.23790534
# Weight              1.00000000  0.30827854  0.88735216     0.79219519
# AnkleCirc           0.61160820  1.00000000  0.48485454         0.419049991
# ExtendedBicepsCirc  0.67870883  0.48485454  1.00000000         0.678255131
# ForearmCirc         0.55589819  0.41904999  0.67825513         1.000000000
# WristCirc           0.66450729  0.56619459  0.63212642         0.585588251
#                    WristCirc
# Case Number         0.08184538
# BroznekBF           0.34757276
# SiriBF              0.34657486
# Density            -0.32571598
# Age                 0.21353062
# Weight              0.72977489
# Height              0.32206533
# AdiposityIndex      0.62590659
# FatFreeWeight       0.67335898
# NeckCirc            0.74482640
# ChestCirc           0.66016232
# AbdomenCirc         0.61983243
# HipCirc             0.63008954
# ThighCirc           0.55868478
# KneeCirc            0.66450729
# AnkleCirc           0.56619459
# ExtendedBicepsCirc  0.63212642
# ForearmCirc         0.58558825
# WristCirc           1.00000000

# %% [markdown]
# #### EDA Insights
#
# As expected, the Case Number didn't correlated with anything (duh) and the two BF% equations correlated ridiculously with each other (duh) but some interesting correlations (or lack thereof) included:
# - A very high correlation between Adiposity Index and BF%
# - A very high negative correlation between Density and BF%
# - A high correlation between Chest Circumference and BF%
# - A lack of a correlation between Age and Weight (counterintuitive)
# - A smaller than expected correlation between %BF and Weight (counterintuitive)
# - A lack of a correlation between Fat Free Weight and %BF (expected)
# - A surprisingly high correlations between Chest Circumference and Weight (interesting)
# - A much smaller than expected correlation between %BF and Height (counterintuitive)
#
# Age, Weight, and Height all seem to be relatively normal distributions
#
# There are 252 total observations in the dataset.

# %%
# Problem 1A

# Our response variable (what we're predicting... 'y')
siriBF = data$SiriBF

# Our predictor variables
age = data[,5]
weight = data[,6]
height = data[,7]
circumferences = data[,10:19]
predictors = cbind(age, weight, height, circumferences)

# Our entire relevant dataset - response + predictors
fittingData = cbind(siriBF, predictors)

# Eliminating outliers
fittingDataNoOutliers = fittingData[-c(seq(1, nrow(fittingData))[fittingData$weight > 300],
                                      seq(1, nrow(fittingData))[fittingData$height < 40]
                                     ),]

stopifnot(nrow(fittingDataNoOutliers) == nrow(fittingData) - 2)

# Fitting Data (excluding outliers)
fit = lm(formula=siriBF~., data=fittingDataNoOutliers)
summary(fit)
# Out:
# Call:
# lm(formula = siriBF ~ ., data = fittingDataNoOutliers)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.9900  -3.1244  -0.1674   3.0248   9.8648
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         1.68516   23.37412   0.072 0.942587
# age                 0.07189    0.03217   2.234 0.026389 *
# weight             -0.01762    0.06714  -0.263 0.793153
# height             -0.24675    0.19114  -1.291 0.197989
# NeckCirc           -0.38682    0.23486  -1.647 0.100887
# ChestCirc          -0.11919    0.10825  -1.101 0.272004
# AbdomenCirc         0.90452    0.09140   9.897  < 2e-16 ***
# HipCirc            -0.15878    0.14586  -1.089 0.277446
# ThighCirc           0.17299    0.14683   1.178 0.239926
# KneeCirc           -0.04580    0.24560  -0.186 0.852230
# AnkleCirc           0.18502    0.21985   0.842 0.400862
# ExtendedBicepsCirc  0.17968    0.17039   1.054 0.292732
# ForearmCirc         0.27605    0.20692   1.334 0.183454
# WristCirc          -1.80162    0.53304  -3.380 0.000848 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.255 on 236 degrees of freedom
# Multiple R-squared:  0.7505,	Adjusted R-squared:  0.7368
# F-statistic: 54.61 on 13 and 236 DF,  p-value: < 2.2e-16

# %%
# Problem 1B

# Resource: Interpreting linear model fit summaries - https://feliperego.github.io/blog/2015/10/23/Interpreting-Model-Output-In-R
